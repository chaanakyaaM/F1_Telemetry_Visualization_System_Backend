# %%
import fastf1
import matplotlib.pyplot as plt

session = fastf1.get_session(2023, "Bahrain", "R")
session.load()

circuit_info = session.get_circuit_info()
track = circuit_info.corners
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (235.89 MB) C:\Users\DELL\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_infox - Race [v3.7.0]
#
# driver_infoox - Race [v3.7.0]
#
#
# req            INFO 	Using cached data for session_status_data
# lap_counttatus_data
#
# req            INFO 	Using cached data for track_status_data
# _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...ing_app_data
#
# req            INFO 	Using cached data for car_datapp_data
#
#
# position_datata
#
#
#
# req            INFO 	Using cached data for weather_data
# race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '55', '44', '18', '63', '77', '10', '23', '22', '2', '20', '21', '27', '24', '4', '31', '16', '81']

# %%
track_df = session.laps.pick_fastest().get_telemetry()[["X", "Y"]]
track_df
# Out:
#               X            Y
# 2   -378.932807  1302.940269
# 3   -375.548141  1365.155731
# 4   -371.000000  1460.000000
# 5   -366.763432  1554.794166
# 6   -361.000000  1684.000000
# ..          ...          ...
# 726 -401.886110   837.094757
# 727 -397.000000   928.000000
# 728 -387.000000  1137.000000
# 729 -386.107872  1155.324567
# 730 -382.587475  1225.854207
#
# [729 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(track_df['X'],track_df['Y'])
