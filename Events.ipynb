# %%
import os
import fastf1


schedule = fastf1.get_event_schedule(2025)
schedule.columns
# Out:
# Index(['RoundNumber', 'Country', 'Location', 'OfficialEventName', 'EventDate',
#        'EventName', 'EventFormat', 'Session1', 'Session1Date',
#        'Session1DateUtc', 'Session2', 'Session2Date', 'Session2DateUtc',
#        'Session3', 'Session3Date', 'Session3DateUtc', 'Session4',
#        'Session4Date', 'Session4DateUtc', 'Session5', 'Session5Date',
#        'Session5DateUtc', 'F1ApiSupport'],
#       dtype='object')

# %%
schedule["EventName"]
# Out:
# 0            Pre-Season Testing
# 1         Australian Grand Prix
# 2            Chinese Grand Prix
# 3           Japanese Grand Prix
# 4            Bahrain Grand Prix
# 5      Saudi Arabian Grand Prix
# 6              Miami Grand Prix
# 7     Emilia Romagna Grand Prix
# 8             Monaco Grand Prix
# 9            Spanish Grand Prix
# 10          Canadian Grand Prix
# 11          Austrian Grand Prix
# 12           British Grand Prix
# 13           Belgian Grand Prix
# 14         Hungarian Grand Prix
# 15             Dutch Grand Prix
# 16           Italian Grand Prix
# 17        Azerbaijan Grand Prix
# 18         Singapore Grand Prix
# 19     United States Grand Prix
# 20       Mexico City Grand Prix
# 21         São Paulo Grand Prix
# 22         Las Vegas Grand Prix
# 23             Qatar Grand Prix
# 24         Abu Dhabi Grand Prix
# Name: EventName, dtype: object

# %%
import pandas as pd
data = fastf1.get_event(gp=23,year=2025)

df = pd.DataFrame(data)
df
# Out:
#                                                               23
# RoundNumber                                                   23
# Country                                                    Qatar
# Location                                                  Lusail
# OfficialEventName  FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2025
# EventDate                                    2025-11-30 00:00:00
# EventName                                       Qatar Grand Prix
# EventFormat                                    sprint_qualifying
# Session1                                              Practice 1
# Session1Date                           2025-11-28 16:30:00+03:00
# Session1DateUtc                              2025-11-28 13:30:00
# Session2                                       Sprint Qualifying
# Session2Date                           2025-11-28 20:30:00+03:00
# Session2DateUtc                              2025-11-28 17:30:00
# ...

# %%
year = 2025
session = fastf1.get_session(year, 22, "R")
# Get event schedule for that year
schedule = fastf1.get_event_schedule(year)

# Grab the EventName from the session (always available)
event_name = session.event["EventName"]

# Find that event in the schedule
event_row = schedule[schedule["EventName"] == event_name].iloc[0]

# Use the official event name as a proxy for track identity
track_or_event_name = event_row["OfficialEventName"]



# Load only laps and telemetry — no weather, messages, etc.
session.load(laps=True, telemetry=True)

# Pick the fastest lap
fastest_lap = session.laps.pick_fastest()
# Extract only the X/Y coordinates
track_coords = fastest_lap.get_telemetry()[["X", "Y"]]
# path = "M " + " L ".join(f"{x},{y}" for x, y in zip(track_coords["X"], track_coords["Y"]))
path = "M " + "\n".join(f"L {x},{y}" for x, y in zip(track_coords["X"], track_coords["Y"]))
# Out:
# core           INFO 	Loading data for Las Vegas Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# driver_infoo
#
# req            INFO 	Using cached data for session_status_data
# lap_counttatus_data
#
# req            INFO 	Using cached data for track_status_data
# _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...ing_app_data
#
# WARNING 	Fixed incorrect tyre stint information for driver '63'
# req            INFO 	Using cached data for car_data driver '63'
#
# position_dataer '63'
#
#
# req            INFO 	Using cached data for weather_data
# race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '63', '12', '16', '55', '6', '27', '44', '31', '87', '14', '22', '10', '30', '43', '23', '5', '18', '4', '81']
# DONE!

# %%
session = fastf1.get_session(2025, 22, "R")
session.load(laps=True, telemetry=True)

# Get event schedule for that year
schedule = fastf1.get_event_schedule(2025)

# Grab the EventName from the session (always available)
event_name = session.event["EventName"]

# Find that event in the schedule
event_row = schedule[schedule["EventName"] == event_name].iloc[0]

# Use the official event name as a proxy for track identity
track_or_event_name = event_row["OfficialEventName"]

print(track_or_event_name)
# Out:
# core           INFO 	Loading data for Las Vegas Grand Prix - Race [v3.7.0]
# req            INFO 	Using cached data for session_info
# driver_infoo
#
# req            INFO 	Using cached data for session_status_data
# lap_counttatus_data
#
# req            INFO 	Using cached data for track_status_data
# _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...ing_app_data
#
# WARNING 	Fixed incorrect tyre stint information for driver '63'
# req            INFO 	Using cached data for car_data driver '63'
#
# position_dataer '63'
#
#
# req            INFO 	Using cached data for weather_data
# race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '63', '12', '16', '55', '6', '27', '44', '31', '87', '14', '22', '10', '30', '43', '23', '5', '18', '4', '81']
# FORMULA 1 HEINEKEN LAS VEGAS GRAND PRIX 2025

# %%
event_name
# Out:
# 'Las Vegas Grand Prix'
