# %%
import fastf1
import pandas as pd

session = fastf1.get_session(2020, 1, "R")
session.load()

lap = session.laps.pick_driver("VER").pick_fastest()
telemetry = lap.get_telemetry()

telemetry
# Out:
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.7.0]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...ion_info. Loading data...
#
# req            INFO 	Data has been written to cache!n_info. Loading data...
#
#
# No cached data found for driver_info. Loading data....
#
#
#
# _api           INFO 	Fetching driver list...g data....
#
#
#
#
# req            INFO 	Data has been written to cache!..
#
#
#
#
#
# No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...g data...
#
# req            INFO 	Data has been written to cache!g data...
#
#
# No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...a...
#
# req            INFO 	Data has been written to cache!
#
# No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...g data...
# ...

# %%
schedule = fastf1.get_event_schedule(2021)
schedule
# Out:
#     RoundNumber        Country           Location  \
# 0             0        Bahrain            Bahrain
# 1             1        Bahrain             Sakhir
# 2             2          Italy              Imola
# 3             3       Portugal           Portimão
# 4             4          Spain          Barcelona
# 5             5         Monaco        Monte Carlo
# 6             6     Azerbaijan               Baku
# 7             7         France       Le Castellet
# 8             8        Austria          Spielberg
# 9             9        Austria          Spielberg
# 10           10  Great Britain        Silverstone
# 11           11        Hungary           Budapest
# 12           12        Belgium  Spa-Francorchamps
# 13           13    Netherlands          Zandvoort
# 14           14          Italy              Monza
# 15           15         Russia              Sochi
# 16           16         Turkey           Istanbul
# 17           17  United States             Austin
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 726 entries, 2 to 727
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   726 non-null    datetime64[ns]
#  1   SessionTime            726 non-null    timedelta64[ns]
#  2   DriverAhead            726 non-null    object
#  3   DistanceToDriverAhead  0 non-null      float64
#  4   Time                   726 non-null    timedelta64[ns]
#  5   RPM                    726 non-null    float64
#  6   Speed                  726 non-null    float64
#  7   nGear                  726 non-null    int64
#  8   Throttle               726 non-null    float64
#  9   Brake                  726 non-null    bool
#  10  DRS                    726 non-null    int64
#  11  Source                 726 non-null    object
#  12  Distance               726 non-null    float64
#  13  RelativeDistance       726 non-null    float64
# ...

# %%
df.drop(columns=["DriverAhead","DistanceToDriverAhead","Status","DRS","Source"],inplace=True)
df.head()
# Out:
#                      Date            SessionTime                   Time  \
# 2 2023-03-05 16:14:59.563 0 days 02:13:57.714000        0 days 00:00:00
# 3 2023-03-05 16:14:59.625 0 days 02:13:57.776000 0 days 00:00:00.062000
# 4 2023-03-05 16:14:59.704 0 days 02:13:57.855000 0 days 00:00:00.141000
# 5 2023-03-05 16:14:59.825 0 days 02:13:57.976000 0 days 00:00:00.262000
# 6 2023-03-05 16:14:59.984 0 days 02:13:58.135000 0 days 00:00:00.421000
#
#             RPM       Speed  nGear  Throttle  Brake   Distance  \
# 2  11271.212513  284.412500      7     100.0  False   0.010802
# 3  11283.870820  284.670833      7     100.0  False   4.920572
# 4  11300.000000  285.000000      7     100.0  False  11.190000
# 5  11338.460694  285.864285      7     100.0  False  20.821555
# 6  11389.000000  287.000000      7     100.0  False  33.512222
#
#    RelativeDistance           X            Y           Z
# 2          0.000002 -382.256646  1221.030661 -158.981903
# ...

# %%
df['Time_sec'] = df['Time'].dt.total_seconds()
df['Speed'] = df['Speed'].round(2)
df["X"] = df["X"].round(3)
df["Y"] = df["Y"].round(3)
df["Z"] = df["Z"].round(3)
df['RPM'] = df["RPM"].round(3)
df['Distance'] = df["Distance"].round(3)
df.drop(columns='Time',inplace=True)

# %%
df.head()
# Out:
#                      Date            SessionTime        RPM   Speed  nGear  \
# 2 2023-03-05 16:14:59.563 0 days 02:13:57.714000  11271.213  284.41      7
# 3 2023-03-05 16:14:59.625 0 days 02:13:57.776000  11283.871  284.67      7
# 4 2023-03-05 16:14:59.704 0 days 02:13:57.855000  11300.000  285.00      7
# 5 2023-03-05 16:14:59.825 0 days 02:13:57.976000  11338.461  285.86      7
# 6 2023-03-05 16:14:59.984 0 days 02:13:58.135000  11389.000  287.00      7
#
#    Throttle  Brake  Distance  RelativeDistance        X         Y        Z  \
# 2     100.0  False     0.011          0.000002 -382.257  1221.031 -158.982
# 3     100.0  False     4.921          0.000915 -380.000  1270.000 -159.000
# 4     100.0  False    11.190          0.002082 -377.234  1332.494 -159.037
# 5     100.0  False    20.822          0.003873 -373.000  1429.000 -159.000
# 6     100.0  False    33.512          0.006234 -366.815  1558.805 -158.462
#
#    Time_sec
# 2     0.000
# 3     0.062
# 4     0.141
# ...

# %%
ndf = df.loc[:, ["X", "Y"]].copy()

path = "M " + " L ".join(f"{x},{y}" for x, y in zip(ndf["X"], ndf["Y"]))

path
# Out:
# 'M -382.257,1221.031\n L -380.0,1270.0\n L -377.234,1332.494\n L -373.0,1429.0\n L -366.815,1558.805\n L -360.0,1700.0\n L -356.521,1775.204\n L -349.371,1935.559\n L -345.0,2038.0\n L -339.897,2171.714\n L -334.0,2330.0\n L -325.981,2533.239\n L -325.0,2557.0\n L -319.755,2674.513\n L -312.0,2819.0\n L -310.616,2848.244\n L -306.0,2950.0\n L -297.0,3154.0\n L -295.34,3189.477\n L -290.0,3302.0\n L -288.487,3335.236\n L -281.686,3498.844\n L -281.0,3517.0\n L -274.615,3698.819\n L -274.0,3716.0\n L -269.0,3849.0\n L -264.0,3982.0\n L -262.642,4019.051\n L -253.301,4279.756\n L -252.0,4316.0\n L -246.045,4482.665\n L -246.0,4484.0\n L -238.198,4716.49\n L -236.0,4770.0\n L -233.0,4837.0\n L -228.737,4952.934\n L -225.0,5073.0\n L -223.432,5122.082\n L -219.08,5257.509\n L -218.0,5293.0\n L -214.054,5426.312\n L -214.0,5428.0\n L -208.0,5597.0\n L -206.806,5630.04\n L -202.0,5766.0\n L -199.715,5833.462\n L -196.0,5952.0\n L -192.0,6105.0\n L -190.886,6146.643\n L -182.0,6466.0\n L -18
# ...

# %%
df
# Out:
#                        Date            SessionTime        RPM   Speed  nGear  \
# 2   2023-03-05 16:14:59.563 0 days 02:13:57.714000  11271.213  284.41      7
# 3   2023-03-05 16:14:59.625 0 days 02:13:57.776000  11283.871  284.67      7
# 4   2023-03-05 16:14:59.704 0 days 02:13:57.855000  11300.000  285.00      7
# 5   2023-03-05 16:14:59.825 0 days 02:13:57.976000  11338.461  285.86      7
# 6   2023-03-05 16:14:59.984 0 days 02:13:58.135000  11389.000  287.00      7
# ..                      ...                    ...        ...     ...    ...
# 723 2023-03-05 16:16:35.366 0 days 02:15:33.517000  11172.638  282.28      7
# 724 2023-03-05 16:16:35.504 0 days 02:15:33.655000  11208.000  284.00      7
# 725 2023-03-05 16:16:35.666 0 days 02:15:33.817000  11212.050  284.81      7
# 726 2023-03-05 16:16:35.704 0 days 02:15:33.855000  11213.000  285.00      7
# 727 2023-03-05 16:16:35.799 0 days 02:15:33.950000  11252.979  285.40      7
#
# ...

# %%
ndf["time"] = df['Time_sec']
ndf["speed"] = df['Speed']

# %%
ndf
# Out:
#            X         Y           x           y    time   speed
# 17  -310.616  2848.244  386.660065  573.889324   2.021  295.00
# 22  -288.487  3335.236  368.651452  571.716125   2.581  297.00
# 27  -269.000  3849.000  350.669819  569.650143   3.223  300.01
# 32  -246.045  4482.665  333.763568  567.749231   3.981  302.00
# 37  -228.737  4952.934  316.218144  565.921462   4.541  304.00
# ..       ...       ...         ...         ...     ...     ...
# 697 -527.000 -1494.000  532.044292  594.782723  92.602  235.00
# 702 -505.000 -1096.000  517.898897  592.830355  93.182  239.02
# 707 -478.027  -588.508  502.257050  590.356897  93.941  260.00
# 712 -450.000   -85.000  486.500716  587.850173  94.502  270.02
# 17  -310.616  2848.244  386.660065  573.889324   2.021  295.00
#
# [141 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["X"],df["Y"])

# %%
data = df[["Time_sec", "X", "Y", "Speed"]].to_dict(orient="records")
# data
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = df[["Time_sec", "X", "Y", "Speed"]].to_dict(orient="records")
#       2 # data
#
# NameError: name 'df' is not defined
